# %% [markdown]
# 🏦 India Bank Customer Churn Prediction System

# %% [markdown]
# 1.Import libraries and load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")

df = pd.read_csv(r"C:\Users\dhama\Desktop\IndiaBankChurnPrediction\indian_bank_customer_churn.csv")  

df.head()
# Out:
#    CustomerID  Age  Gender        State Account_Type  Tenure_Years  \
# 0     1000001   56  Female    Telangana      Savings            12
# 1     1000002   69    Male   Tamil Nadu      Savings             6
# 2     1000003   46    Male      Gujarat       Salary             0
# 3     1000004   32  Female    Telangana      Savings            11
# 4     1000005   60    Male  Maharashtra      Savings             6
#
#    Balance_INR  Num_Products  Has_Credit_Card  Is_Active_Member  \
# 0    385096.49             4                1                 1
# 1     63323.38             2                0                 1
# 2     78554.85             4                1                 1
# 3    159944.95             4                1                 1
# 4    193704.64             1                1                 1
#
#    Estimated_Salary_INR  Credit_Score  Churn
# 0               2012330           592      0
# 1               1349914           656      1
# ...

# %% [markdown]
# 2.Churn Distribution

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 0    62180
# 1    37820
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# 0    62.18
# 1    37.82
# Name: proportion, dtype: float64

# %% [markdown]
# 3.Overall Churn Distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Churn", data=df)
plt.title("Overall Churn Distribution")
plt.xticks([0,1], ["Retained", "Churned"])
plt.xlabel("Customer Status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 4.Churn by Gender

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Gender", hue="Churn", data=df)
plt.title("Churn by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Churn", labels=["Retained", "Churned"])
plt.show()

# %% [markdown]
# 5.Churn by Geography(State)

# %%
plt.figure(figsize=(10,4))
sns.countplot(x="State", hue="Churn", data=df)
plt.title("Churn by State")
plt.xlabel("State")
plt.ylabel("Count")
plt.legend(title="Churn", labels=["Retained", "Churned"])
plt.show()

# %% [markdown]
# 6.Churn by Active Member Status

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Is_Active_Member", hue="Churn", data=df)
plt.title("Churn vs Active Member Status")
plt.xticks([0,1], ["Inactive", "Active"])
plt.xlabel("Active Member")
plt.ylabel("Count")
plt.legend(title="Churn", labels=["Retained", "Churned"])
plt.show()

# %% [markdown]
# 7.Churn by Credit Score

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Churn", y="Credit_Score", data=df)
plt.title("Credit Score vs Churn")
plt.xticks([0,1], ["Retained", "Churned"])
plt.xlabel("Customer Status")
plt.ylabel("Credit Score")
plt.show()

# %% [markdown]
# 9.Churn by Estimated Salary

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Churn", y="Estimated_Salary_INR", data=df)
plt.title("Estimated Salary vs Churn")
plt.xticks([0,1], ["Retained", "Churned"])
plt.xlabel("Customer Status")
plt.ylabel("Estimated Salary")
plt.show()

# %% [markdown]
# 10.Churn rate by Gender

# %%
churn_rate_gender = df.groupby("Gender")["Churn"].mean() * 100
churn_rate_gender
# Out:
# Gender
# Female    37.512037
# Male      38.126097
# Name: Churn, dtype: float64

# %%
churn_rate_gender.plot(kind="bar", figsize=(5,4))
plt.title("Churn Rate by Gender (%)")
plt.ylabel("Churn Rate (%)")
plt.show()

# %% [markdown]
# 11.Churn rate by Active Member

# %%
churn_rate_active = df.groupby("Is_Active_Member")["Churn"].mean() * 100
churn_rate_active
# Out:
# Is_Active_Member
# 0    52.740205
# 1    27.844152
# Name: Churn, dtype: float64

# %%
churn_rate_active.plot(kind="bar", figsize=(5,4))
plt.title("Churn Rate by Active Membership (%)")
plt.xticks([0,1], ["Inactive", "Active"])
plt.ylabel("Churn Rate (%)")
plt.show()
